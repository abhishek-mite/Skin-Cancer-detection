# %%
import os, glob
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import Callback,EarlyStopping
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.metrics import  classification_report

# %%
file_path = 'archive (2)/data/train'

# %%
name_class = os.listdir(file_path)
name_class
# Out:
# ['benign', 'malignant']

# %%
filepaths = list(glob.glob(file_path+'/**/*.*'))

# %%
filepaths
# Out:
# ['archive (2)/data/train\\benign\\100.jpg',
#  'archive (2)/data/train\\benign\\1000.jpg',
#  'archive (2)/data/train\\benign\\1001.jpg',
#  'archive (2)/data/train\\benign\\1002.jpg',
#  'archive (2)/data/train\\benign\\1004.jpg',
#  'archive (2)/data/train\\benign\\1005.jpg',
#  'archive (2)/data/train\\benign\\1007.jpg',
#  'archive (2)/data/train\\benign\\1008.jpg',
#  'archive (2)/data/train\\benign\\1009.jpg',
#  'archive (2)/data/train\\benign\\101.jpg',
#  'archive (2)/data/train\\benign\\1010.jpg',
#  'archive (2)/data/train\\benign\\1011.jpg',
#  'archive (2)/data/train\\benign\\1012.jpg',
#  'archive (2)/data/train\\benign\\1014.jpg',
#  'archive (2)/data/train\\benign\\1015.jpg',
#  'archive (2)/data/train\\benign\\1016.jpg',
#  'archive (2)/data/train\\benign\\1017.jpg',
#  'archive (2)/data/train\\benign\\102.jpg',
#  'archive (2)/data/train\\benign\\1020.jpg',
#  'archive (2)/data/train\\benign\\1021.jpg',
#  'archive (2)/data/train\\benign\\1022.jpg',
#  'archive (2)/data/train\\benign\\1024.jpg',
#  'archive (2)/data/train\\benign\\1026.jpg',
#  'archive (2)/data/train\\benign\\1027.jpg',
#  'archive (2)/data/train\\benign\\1028.jpg',
#  'archive (2)/data/train\\benign\\103.jpg',
#  'archive (2)/data/train\\benign\\1030.jpg',
#  'archive (2)/data/train\\benign\\1031.jpg',
#  'archive (2)/data/train\\benign\\1032.jpg',
#  'archive (2)/data/train\\benign\\1035.jpg',
#  'archive (2)/data/train\\benign\\1036.jpg',
#  'archive (2)/data/train\\benign\\1037.jpg',
#  'archive (2)/data/train\\benign\\1038.jpg',
#  'archive (2)/data/train\\benign\\1039.jpg',
#  'archive (2)/data/train\\benign\\104.jpg',
#  'archive (2)/data/train\\benign\\1040.jpg',
#  'archive (2)/data/train\\benign\\1041.jpg',
#  'archive (2)/data/train\\benign\\1043.jpg',
#  'archive (2)/data/train\\benign\\1045.jpg',
#  'archive (2)/data/train\\benign\\1046.jpg',
#  'archive (2)/data/train\\benign\\1047.jpg',
#  'archive (2)/data/train\\benign\\1048.jpg',
#  'archive (2)/data/train\\benign\\1049.jpg',
#  'archive (2)/data/train\\benign\\1050.jpg',
#  'archive (2)/data/train\\benign\\1051.jpg',
#  'archive (2)/data/train\\benign\\1052.jpg',
#  'archive (2)/data/train\\benign\\1053.jpg',
#  'archive (2)/data/train\\benign\\1054.jpg',
#  'archive (2)/data/train\\benign\\1056.jpg',
#  'archive (2)/data/train\\benign\\1057.jpg',
#  'archive (2)/data/train\\benign\\1058.jpg',
#  'archive (2)/data/train\\benign\\1059.jpg',
#  'archive (2)/data/train\\benign\\106.jpg',
#  'archive (2)/data/train\\benign\\1060.jpg',
#  'archive (2)/data/train\\benign\\1062.jpg',
#  'archive (2)/data/train\\benign\\1063.jpg',
#  'archive (2)/data/train\\benign\\1064.jpg',
#  'archive (2)/data/train\\benign\\1065.jpg',
#  'archive (2)/data/train\\benign\\1066.jpg',
#  'archive (2)/data/train\\benign\\1067.jpg',
#  'archive (2)/data/train\\benign\\1068.jpg',
#  'archive (2)/data/train\\benign\\1069.jpg',
#  'archive (2)/data/train\\benign\\107.jpg',
#  'archive (2)/data/train\\benign\\1071.jpg',
#  'archive (2)/data/train\\benign\\1072.jpg',
#  'archive (2)/data/train\\benign\\1073.jpg',
#  'archive (2)/data/train\\benign\\1075.jpg',
#  'archive (2)/data/train\\benign\\1076.jpg',
#  'archive (2)/data/train\\benign\\1078.jpg',
#  'archive (2)/data/train\\benign\\1079.jpg',
#  'archive (2)/data/train\\benign\\108.jpg',
#  'archive (2)/data/train\\benign\\1081.jpg',
#  'archive (2)/data/train\\benign\\1082.jpg',
#  'archive (2)/data/train\\benign\\1083.jpg',
#  'archive (2)/data/train\\benign\\1084.jpg',
#  'archive (2)/data/train\\benign\\1085.jpg',
#  'archive (2)/data/train\\benign\\1086.jpg',
#  'archive (2)/data/train\\benign\\1089.jpg',
#  'archive (2)/data/train\\benign\\109.jpg',
#  'archive (2)/data/train\\benign\\1090.jpg',
#  'archive (2)/data/train\\benign\\1091.jpg',
#  'archive (2)/data/train\\benign\\1093.jpg',
#  'archive (2)/data/train\\benign\\1094.jpg',
#  'archive (2)/data/train\\benign\\1095.jpg',
#  'archive (2)/data/train\\benign\\1096.jpg',
#  'archive (2)/data/train\\benign\\1097.jpg',
#  'archive (2)/data/train\\benign\\1098.jpg',
#  'archive (2)/data/train\\benign\\1099.jpg',
#  'archive (2)/data/train\\benign\\110.jpg',
#  'archive (2)/data/train\\benign\\1100.jpg',
#  'archive (2)/data/train\\benign\\1101.jpg',
#  'archive (2)/data/train\\benign\\1102.jpg',
#  'archive (2)/data/train\\benign\\1103.jpg',
#  'archive (2)/data/train\\benign\\1104.jpg',
#  'archive (2)/data/train\\benign\\1105.jpg',
#  'archive (2)/data/train\\benign\\1106.jpg',
#  'archive (2)/data/train\\benign\\1107.jpg',
#  'archive (2)/data/train\\benign\\1108.jpg',
#  'archive (2)/data/train\\benign\\1109.jpg',
#  'archive (2)/data/train\\benign\\111.jpg',
#  'archive (2)/data/train\\benign\\1111.jpg',
#  'archive (2)/data/train\\benign\\1113.jpg',
#  'archive (2)/data/train\\benign\\1114.jpg',
#  'archive (2)/data/train\\benign\\1116.jpg',
#  'archive (2)/data/train\\benign\\1117.jpg',
#  'archive (2)/data/train\\benign\\1119.jpg',
#  'archive (2)/data/train\\benign\\112.jpg',
#  'archive (2)/data/train\\benign\\1120.jpg',
#  'archive (2)/data/train\\benign\\1121.jpg',
#  'archive (2)/data/train\\benign\\1122.jpg',
#  'archive (2)/data/train\\benign\\1123.jpg',
#  'archive (2)/data/train\\benign\\1124.jpg',
#  'archive (2)/data/train\\benign\\1127.jpg',
#  'archive (2)/data/train\\benign\\1128.jpg',
#  'archive (2)/data/train\\benign\\1129.jpg',
#  'archive (2)/data/train\\benign\\113.jpg',
#  'archive (2)/data/train\\benign\\1131.jpg',
#  'archive (2)/data/train\\benign\\1132.jpg',
#  'archive (2)/data/train\\benign\\1133.jpg',
#  'archive (2)/data/train\\benign\\1136.jpg',
#  'archive (2)/data/train\\benign\\1137.jpg',
#  'archive (2)/data/train\\benign\\1138.jpg',
#  'archive (2)/data/train\\benign\\114.jpg',
#  'archive (2)/data/train\\benign\\1140.jpg',
#  'archive (2)/data/train\\benign\\1141.jpg',
#  'archive (2)/data/train\\benign\\1142.jpg',
#  'archive (2)/data/train\\benign\\1144.jpg',
#  'archive (2)/data/train\\benign\\1145.jpg',
#  'archive (2)/data/train\\benign\\1147.jpg',
#  'archive (2)/data/train\\benign\\1148.jpg',
#  'archive (2)/data/train\\benign\\1149.jpg',
#  'archive (2)/data/train\\benign\\115.jpg',
#  'archive (2)/data/train\\benign\\1150.jpg',
#  'archive (2)/data/train\\benign\\1152.jpg',
#  'archive (2)/data/train\\benign\\1153.jpg',
#  'archive (2)/data/train\\benign\\1154.jpg',
#  'archive (2)/data/train\\benign\\1156.jpg',
#  'archive (2)/data/train\\benign\\1157.jpg',
#  'archive (2)/data/train\\benign\\1158.jpg',
#  'archive (2)/data/train\\benign\\1159.jpg',
#  'archive (2)/data/train\\benign\\116.jpg',
#  'archive (2)/data/train\\benign\\1160.jpg',
#  'archive (2)/data/train\\benign\\1161.jpg',
#  'archive (2)/data/train\\benign\\1162.jpg',
#  'archive (2)/data/train\\benign\\1163.jpg',
#  'archive (2)/data/train\\benign\\1164.jpg',
#  'archive (2)/data/train\\benign\\1165.jpg',
#  'archive (2)/data/train\\benign\\1167.jpg',
#  'archive (2)/data/train\\benign\\1168.jpg',
#  'archive (2)/data/train\\benign\\1169.jpg',
#  'archive (2)/data/train\\benign\\117.jpg',
#  'archive (2)/data/train\\benign\\1171.jpg',
#  'archive (2)/data/train\\benign\\1172.jpg',
#  'archive (2)/data/train\\benign\\1174.jpg',
#  'archive (2)/data/train\\benign\\1175.jpg',
#  'archive (2)/data/train\\benign\\1176.jpg',
#  'archive (2)/data/train\\benign\\1178.jpg',
#  'archive (2)/data/train\\benign\\1179.jpg',
#  'archive (2)/data/train\\benign\\118.jpg',
#  'archive (2)/data/train\\benign\\1181.jpg',
#  'archive (2)/data/train\\benign\\1182.jpg',
#  'archive (2)/data/train\\benign\\1184.jpg',
#  'archive (2)/data/train\\benign\\1185.jpg',
#  'archive (2)/data/train\\benign\\1186.jpg',
#  'archive (2)/data/train\\benign\\1187.jpg',
#  'archive (2)/data/train\\benign\\1188.jpg',
#  'archive (2)/data/train\\benign\\1189.jpg',
#  'archive (2)/data/train\\benign\\1190.jpg',
#  'archive (2)/data/train\\benign\\1192.jpg',
#  'archive (2)/data/train\\benign\\1193.jpg',
#  'archive (2)/data/train\\benign\\1194.jpg',
#  'archive (2)/data/train\\benign\\1195.jpg',
#  'archive (2)/data/train\\benign\\1196.jpg',
#  'archive (2)/data/train\\benign\\1197.jpg',
#  'archive (2)/data/train\\benign\\1198.jpg',
#  'archive (2)/data/train\\benign\\1199.jpg',
#  'archive (2)/data/train\\benign\\12.jpg',
#  'archive (2)/data/train\\benign\\120.jpg',
#  'archive (2)/data/train\\benign\\1201.jpg',
#  'archive (2)/data/train\\benign\\1202.jpg',
#  'archive (2)/data/train\\benign\\1204.jpg',
#  'archive (2)/data/train\\benign\\1205.jpg',
#  'archive (2)/data/train\\benign\\1206.jpg',
#  'archive (2)/data/train\\benign\\1207.jpg',
#  'archive (2)/data/train\\benign\\1209.jpg',
#  'archive (2)/data/train\\benign\\121.jpg',
#  'archive (2)/data/train\\benign\\1210.jpg',
#  'archive (2)/data/train\\benign\\1211.jpg',
#  'archive (2)/data/train\\benign\\1212.jpg',
#  'archive (2)/data/train\\benign\\1213.jpg',
#  'archive (2)/data/train\\benign\\1216.jpg',
#  'archive (2)/data/train\\benign\\1217.jpg',
#  'archive (2)/data/train\\benign\\1218.jpg',
#  'archive (2)/data/train\\benign\\1219.jpg',
#  'archive (2)/data/train\\benign\\1220.jpg',
#  'archive (2)/data/train\\benign\\1221.jpg',
#  'archive (2)/data/train\\benign\\1222.jpg',
#  'archive (2)/data/train\\benign\\1223.jpg',
#  'archive (2)/data/train\\benign\\1224.jpg',
#  'archive (2)/data/train\\benign\\1225.jpg',
#  'archive (2)/data/train\\benign\\1227.jpg',
#  'archive (2)/data/train\\benign\\1228.jpg',
#  'archive (2)/data/train\\benign\\1229.jpg',
#  'archive (2)/data/train\\benign\\123.jpg',
#  'archive (2)/data/train\\benign\\1230.jpg',
#  'archive (2)/data/train\\benign\\1232.jpg',
#  'archive (2)/data/train\\benign\\1233.jpg',
#  'archive (2)/data/train\\benign\\1234.jpg',
#  'archive (2)/data/train\\benign\\1235.jpg',
#  'archive (2)/data/train\\benign\\1236.jpg',
#  'archive (2)/data/train\\benign\\1237.jpg',
#  'archive (2)/data/train\\benign\\1238.jpg',
#  'archive (2)/data/train\\benign\\1239.jpg',
#  'archive (2)/data/train\\benign\\124.jpg',
#  'archive (2)/data/train\\benign\\1240.jpg',
#  'archive (2)/data/train\\benign\\1241.jpg',
#  'archive (2)/data/train\\benign\\1245.jpg',
#  'archive (2)/data/train\\benign\\1246.jpg',
#  'archive (2)/data/train\\benign\\1247.jpg',
#  'archive (2)/data/train\\benign\\1248.jpg',
#  'archive (2)/data/train\\benign\\1249.jpg',
#  'archive (2)/data/train\\benign\\125.jpg',
#  'archive (2)/data/train\\benign\\1250.jpg',
#  'archive (2)/data/train\\benign\\1251.jpg',
#  'archive (2)/data/train\\benign\\1252.jpg',
#  'archive (2)/data/train\\benign\\1254.jpg',
#  'archive (2)/data/train\\benign\\1255.jpg',
#  'archive (2)/data/train\\benign\\1256.jpg',
#  'archive (2)/data/train\\benign\\1257.jpg',
#  'archive (2)/data/train\\benign\\1258.jpg',
#  'archive (2)/data/train\\benign\\1259.jpg',
#  'archive (2)/data/train\\benign\\126.jpg',
#  'archive (2)/data/train\\benign\\1260.jpg',
#  'archive (2)/data/train\\benign\\1262.jpg',
#  'archive (2)/data/train\\benign\\1263.jpg',
#  'archive (2)/data/train\\benign\\1264.jpg',
#  'archive (2)/data/train\\benign\\1267.jpg',
#  'archive (2)/data/train\\benign\\1268.jpg',
#  'archive (2)/data/train\\benign\\1270.jpg',
#  'archive (2)/data/train\\benign\\1271.jpg',
#  'archive (2)/data/train\\benign\\1272.jpg',
#  'archive (2)/data/train\\benign\\1274.jpg',
#  'archive (2)/data/train\\benign\\1275.jpg',
#  'archive (2)/data/train\\benign\\1279.jpg',
#  'archive (2)/data/train\\benign\\128.jpg',
#  'archive (2)/data/train\\benign\\1280.jpg',
#  'archive (2)/data/train\\benign\\1281.jpg',
#  'archive (2)/data/train\\benign\\1282.jpg',
#  'archive (2)/data/train\\benign\\1283.jpg',
#  'archive (2)/data/train\\benign\\1284.jpg',
#  'archive (2)/data/train\\benign\\1285.jpg',
#  'archive (2)/data/train\\benign\\1286.jpg',
#  'archive (2)/data/train\\benign\\1287.jpg',
#  'archive (2)/data/train\\benign\\1289.jpg',
#  'archive (2)/data/train\\benign\\129.jpg',
#  'archive (2)/data/train\\benign\\1291.jpg',
#  'archive (2)/data/train\\benign\\1292.jpg',
#  'archive (2)/data/train\\benign\\1293.jpg',
#  'archive (2)/data/train\\benign\\1294.jpg',
#  'archive (2)/data/train\\benign\\1295.jpg',
#  'archive (2)/data/train\\benign\\1296.jpg',
#  'archive (2)/data/train\\benign\\1298.jpg',
#  'archive (2)/data/train\\benign\\13.jpg',
#  'archive (2)/data/train\\benign\\130.jpg',
#  'archive (2)/data/train\\benign\\1300.jpg',
#  'archive (2)/data/train\\benign\\1301.jpg',
#  'archive (2)/data/train\\benign\\1302.jpg',
#  'archive (2)/data/train\\benign\\1303.jpg',
#  'archive (2)/data/train\\benign\\1304.jpg',
#  'archive (2)/data/train\\benign\\1305.jpg',
#  'archive (2)/data/train\\benign\\1306.jpg',
#  'archive (2)/data/train\\benign\\1307.jpg',
#  'archive (2)/data/train\\benign\\1308.jpg',
#  'archive (2)/data/train\\benign\\1309.jpg',
#  'archive (2)/data/train\\benign\\131.jpg',
#  'archive (2)/data/train\\benign\\1311.jpg',
#  'archive (2)/data/train\\benign\\1312.jpg',
#  'archive (2)/data/train\\benign\\1313.jpg',
#  'archive (2)/data/train\\benign\\1314.jpg',
#  'archive (2)/data/train\\benign\\1315.jpg',
#  'archive (2)/data/train\\benign\\1316.jpg',
#  'archive (2)/data/train\\benign\\1317.jpg',
#  'archive (2)/data/train\\benign\\1318.jpg',
#  'archive (2)/data/train\\benign\\132.jpg',
#  'archive (2)/data/train\\benign\\1320.jpg',
#  'archive (2)/data/train\\benign\\1323.jpg',
#  'archive (2)/data/train\\benign\\1324.jpg',
#  'archive (2)/data/train\\benign\\1325.jpg',
#  'archive (2)/data/train\\benign\\1326.jpg',
#  'archive (2)/data/train\\benign\\1327.jpg',
#  'archive (2)/data/train\\benign\\1328.jpg',
#  'archive (2)/data/train\\benign\\1329.jpg',
#  'archive (2)/data/train\\benign\\133.jpg',
#  'archive (2)/data/train\\benign\\1330.jpg',
#  'archive (2)/data/train\\benign\\1331.jpg',
#  'archive (2)/data/train\\benign\\1332.jpg',
#  'archive (2)/data/train\\benign\\1333.jpg',
#  'archive (2)/data/train\\benign\\1335.jpg',
#  'archive (2)/data/train\\benign\\1336.jpg',
#  'archive (2)/data/train\\benign\\1337.jpg',
#  'archive (2)/data/train\\benign\\1338.jpg',
#  'archive (2)/data/train\\benign\\1339.jpg',
#  'archive (2)/data/train\\benign\\134.jpg',
#  'archive (2)/data/train\\benign\\1340.jpg',
#  'archive (2)/data/train\\benign\\1341.jpg',
#  'archive (2)/data/train\\benign\\1344.jpg',
#  'archive (2)/data/train\\benign\\1345.jpg',
#  'archive (2)/data/train\\benign\\1346.jpg',
#  'archive (2)/data/train\\benign\\1347.jpg',
#  'archive (2)/data/train\\benign\\1348.jpg',
#  'archive (2)/data/train\\benign\\1349.jpg',
#  'archive (2)/data/train\\benign\\135.jpg',
#  'archive (2)/data/train\\benign\\1351.jpg',
#  'archive (2)/data/train\\benign\\1352.jpg',
#  'archive (2)/data/train\\benign\\1353.jpg',
#  'archive (2)/data/train\\benign\\1355.jpg',
#  'archive (2)/data/train\\benign\\1356.jpg',
#  'archive (2)/data/train\\benign\\1358.jpg',
#  'archive (2)/data/train\\benign\\136.jpg',
#  'archive (2)/data/train\\benign\\1360.jpg',
#  'archive (2)/data/train\\benign\\1361.jpg',
#  'archive (2)/data/train\\benign\\1363.jpg',
#  'archive (2)/data/train\\benign\\1364.jpg',
#  'archive (2)/data/train\\benign\\1366.jpg',
#  'archive (2)/data/train\\benign\\1368.jpg',
#  'archive (2)/data/train\\benign\\1369.jpg',
#  'archive (2)/data/train\\benign\\137.jpg',
#  'archive (2)/data/train\\benign\\1370.jpg',
#  'archive (2)/data/train\\benign\\1371.jpg',
#  'archive (2)/data/train\\benign\\1372.jpg',
#  'archive (2)/data/train\\benign\\1374.jpg',
#  'archive (2)/data/train\\benign\\1375.jpg',
#  'archive (2)/data/train\\benign\\1379.jpg',
#  'archive (2)/data/train\\benign\\138.jpg',
#  'archive (2)/data/train\\benign\\1380.jpg',
#  'archive (2)/data/train\\benign\\1382.jpg',
#  'archive (2)/data/train\\benign\\1383.jpg',
#  'archive (2)/data/train\\benign\\1384.jpg',
#  'archive (2)/data/train\\benign\\1385.jpg',
#  'archive (2)/data/train\\benign\\1386.jpg',
#  'archive (2)/data/train\\benign\\1387.jpg',
#  'archive (2)/data/train\\benign\\1388.jpg',
#  'archive (2)/data/train\\benign\\1389.jpg',
#  'archive (2)/data/train\\benign\\139.jpg',
#  'archive (2)/data/train\\benign\\1390.jpg',
#  'archive (2)/data/train\\benign\\1391.jpg',
#  'archive (2)/data/train\\benign\\1392.jpg',
#  'archive (2)/data/train\\benign\\1394.jpg',
#  'archive (2)/data/train\\benign\\1395.jpg',
#  'archive (2)/data/train\\benign\\1396.jpg',
#  'archive (2)/data/train\\benign\\1397.jpg',
#  'archive (2)/data/train\\benign\\1398.jpg',
#  'archive (2)/data/train\\benign\\1399.jpg',
#  'archive (2)/data/train\\benign\\14.jpg',
#  'archive (2)/data/train\\benign\\1402.jpg',
#  'archive (2)/data/train\\benign\\1403.jpg',
#  'archive (2)/data/train\\benign\\1404.jpg',
#  'archive (2)/data/train\\benign\\1405.jpg',
#  'archive (2)/data/train\\benign\\1406.jpg',
#  'archive (2)/data/train\\benign\\1407.jpg',
#  'archive (2)/data/train\\benign\\1408.jpg',
#  'archive (2)/data/train\\benign\\141.jpg',
#  'archive (2)/data/train\\benign\\1410.jpg',
#  'archive (2)/data/train\\benign\\1411.jpg',
#  'archive (2)/data/train\\benign\\1413.jpg',
#  'archive (2)/data/train\\benign\\1414.jpg',
#  'archive (2)/data/train\\benign\\1416.jpg',
#  'archive (2)/data/train\\benign\\1417.jpg',
#  'archive (2)/data/train\\benign\\1418.jpg',
#  'archive (2)/data/train\\benign\\1419.jpg',
#  'archive (2)/data/train\\benign\\142.jpg',
#  'archive (2)/data/train\\benign\\1420.jpg',
#  'archive (2)/data/train\\benign\\1421.jpg',
#  'archive (2)/data/train\\benign\\1422.jpg',
#  'archive (2)/data/train\\benign\\1423.jpg',
#  'archive (2)/data/train\\benign\\1424.jpg',
#  'archive (2)/data/train\\benign\\1425.jpg',
#  'archive (2)/data/train\\benign\\1426.jpg',
#  'archive (2)/data/train\\benign\\1427.jpg',
#  'archive (2)/data/train\\benign\\1428.jpg',
#  'archive (2)/data/train\\benign\\1429.jpg',
#  'archive (2)/data/train\\benign\\143.jpg',
#  'archive (2)/data/train\\benign\\1430.jpg',
#  'archive (2)/data/train\\benign\\1431.jpg',
#  'archive (2)/data/train\\benign\\1432.jpg',
#  'archive (2)/data/train\\benign\\1433.jpg',
#  'archive (2)/data/train\\benign\\1434.jpg',
#  'archive (2)/data/train\\benign\\1435.jpg',
#  'archive (2)/data/train\\benign\\1436.jpg',
#  'archive (2)/data/train\\benign\\1437.jpg',
#  'archive (2)/data/train\\benign\\1438.jpg',
#  'archive (2)/data/train\\benign\\1439.jpg',
#  'archive (2)/data/train\\benign\\1440.jpg',
#  'archive (2)/data/train\\benign\\1442.jpg',
#  'archive (2)/data/train\\benign\\1444.jpg',
#  'archive (2)/data/train\\benign\\1446.jpg',
#  'archive (2)/data/train\\benign\\1447.jpg',
#  'archive (2)/data/train\\benign\\1449.jpg',
#  'archive (2)/data/train\\benign\\145.jpg',
#  'archive (2)/data/train\\benign\\1450.jpg',
#  'archive (2)/data/train\\benign\\1451.jpg',
#  'archive (2)/data/train\\benign\\1452.jpg',
#  'archive (2)/data/train\\benign\\1453.jpg',
#  'archive (2)/data/train\\benign\\1454.jpg',
#  'archive (2)/data/train\\benign\\1455.jpg',
#  'archive (2)/data/train\\benign\\1456.jpg',
#  'archive (2)/data/train\\benign\\1457.jpg',
#  'archive (2)/data/train\\benign\\1458.jpg',
#  'archive (2)/data/train\\benign\\1459.jpg',
#  'archive (2)/data/train\\benign\\146.jpg',
#  'archive (2)/data/train\\benign\\1460.jpg',
#  'archive (2)/data/train\\benign\\1461.jpg',
#  'archive (2)/data/train\\benign\\1462.jpg',
#  'archive (2)/data/train\\benign\\1463.jpg',
#  'archive (2)/data/train\\benign\\1464.jpg',
#  'archive (2)/data/train\\benign\\1465.jpg',
#  'archive (2)/data/train\\benign\\1467.jpg',
#  'archive (2)/data/train\\benign\\1469.jpg',
#  'archive (2)/data/train\\benign\\1470.jpg',
#  'archive (2)/data/train\\benign\\1472.jpg',
#  'archive (2)/data/train\\benign\\1474.jpg',
#  'archive (2)/data/train\\benign\\1475.jpg',
#  'archive (2)/data/train\\benign\\1476.jpg',
#  'archive (2)/data/train\\benign\\1477.jpg',
#  'archive (2)/data/train\\benign\\1478.jpg',
#  'archive (2)/data/train\\benign\\148.jpg',
#  'archive (2)/data/train\\benign\\1480.jpg',
#  'archive (2)/data/train\\benign\\1482.jpg',
#  'archive (2)/data/train\\benign\\1484.jpg',
#  'archive (2)/data/train\\benign\\1486.jpg',
#  'archive (2)/data/train\\benign\\1487.jpg',
#  'archive (2)/data/train\\benign\\1489.jpg',
#  'archive (2)/data/train\\benign\\149.jpg',
#  'archive (2)/data/train\\benign\\1490.jpg',
#  'archive (2)/data/train\\benign\\1491.jpg',
#  'archive (2)/data/train\\benign\\1493.jpg',
#  'archive (2)/data/train\\benign\\1494.jpg',
#  'archive (2)/data/train\\benign\\1495.jpg',
#  'archive (2)/data/train\\benign\\1496.jpg',
#  'archive (2)/data/train\\benign\\1497.jpg',
#  'archive (2)/data/train\\benign\\1498.jpg',
#  'archive (2)/data/train\\benign\\150.jpg',
#  'archive (2)/data/train\\benign\\1500.jpg',
#  'archive (2)/data/train\\benign\\1501.jpg',
#  'archive (2)/data/train\\benign\\1503.jpg',
#  'archive (2)/data/train\\benign\\1504.jpg',
#  'archive (2)/data/train\\benign\\1505.jpg',
#  'archive (2)/data/train\\benign\\1506.jpg',
#  'archive (2)/data/train\\benign\\1507.jpg',
#  'archive (2)/data/train\\benign\\1508.jpg',
#  'archive (2)/data/train\\benign\\1509.jpg',
#  'archive (2)/data/train\\benign\\151.jpg',
#  'archive (2)/data/train\\benign\\1510.jpg',
#  'archive (2)/data/train\\benign\\1511.jpg',
#  'archive (2)/data/train\\benign\\1512.jpg',
#  'archive (2)/data/train\\benign\\1513.jpg',
#  'archive (2)/data/train\\benign\\1515.jpg',
#  'archive (2)/data/train\\benign\\1517.jpg',
#  'archive (2)/data/train\\benign\\1518.jpg',
#  'archive (2)/data/train\\benign\\152.jpg',
#  'archive (2)/data/train\\benign\\1520.jpg',
#  'archive (2)/data/train\\benign\\1522.jpg',
#  'archive (2)/data/train\\benign\\1523.jpg',
#  'archive (2)/data/train\\benign\\1524.jpg',
#  'archive (2)/data/train\\benign\\1525.jpg',
#  'archive (2)/data/train\\benign\\1526.jpg',
#  'archive (2)/data/train\\benign\\1527.jpg',
#  'archive (2)/data/train\\benign\\1528.jpg',
#  'archive (2)/data/train\\benign\\1529.jpg',
#  'archive (2)/data/train\\benign\\153.jpg',
#  'archive (2)/data/train\\benign\\1531.jpg',
#  'archive (2)/data/train\\benign\\1532.jpg',
#  'archive (2)/data/train\\benign\\1533.jpg',
#  'archive (2)/data/train\\benign\\1534.jpg',
#  'archive (2)/data/train\\benign\\1535.jpg',
#  'archive (2)/data/train\\benign\\1536.jpg',
#  'archive (2)/data/train\\benign\\1539.jpg',
#  'archive (2)/data/train\\benign\\1540.jpg',
#  'archive (2)/data/train\\benign\\1541.jpg',
#  'archive (2)/data/train\\benign\\1542.jpg',
#  'archive (2)/data/train\\benign\\1543.jpg',
#  'archive (2)/data/train\\benign\\1544.jpg',
#  'archive (2)/data/train\\benign\\1546.jpg',
#  'archive (2)/data/train\\benign\\1547.jpg',
#  'archive (2)/data/train\\benign\\1548.jpg',
#  'archive (2)/data/train\\benign\\1549.jpg',
#  'archive (2)/data/train\\benign\\155.jpg',
#  'archive (2)/data/train\\benign\\1550.jpg',
#  'archive (2)/data/train\\benign\\1551.jpg',
#  'archive (2)/data/train\\benign\\1552.jpg',
#  'archive (2)/data/train\\benign\\1553.jpg',
#  'archive (2)/data/train\\benign\\1554.jpg',
#  'archive (2)/data/train\\benign\\1555.jpg',
#  'archive (2)/data/train\\benign\\1556.jpg',
#  'archive (2)/data/train\\benign\\1557.jpg',
#  'archive (2)/data/train\\benign\\1558.jpg',
#  'archive (2)/data/train\\benign\\156.jpg',
#  'archive (2)/data/train\\benign\\1560.jpg',
#  'archive (2)/data/train\\benign\\1561.jpg',
#  'archive (2)/data/train\\benign\\1562.jpg',
#  'archive (2)/data/train\\benign\\1563.jpg',
#  'archive (2)/data/train\\benign\\1564.jpg',
#  'archive (2)/data/train\\benign\\1565.jpg',
#  'archive (2)/data/train\\benign\\1566.jpg',
#  'archive (2)/data/train\\benign\\1567.jpg',
#  'archive (2)/data/train\\benign\\1568.jpg',
#  'archive (2)/data/train\\benign\\1569.jpg',
#  'archive (2)/data/train\\benign\\157.jpg',
#  'archive (2)/data/train\\benign\\1570.jpg',
#  'archive (2)/data/train\\benign\\1571.jpg',
#  'archive (2)/data/train\\benign\\1572.jpg',
#  'archive (2)/data/train\\benign\\1573.jpg',
#  'archive (2)/data/train\\benign\\1574.jpg',
#  'archive (2)/data/train\\benign\\1575.jpg',
#  'archive (2)/data/train\\benign\\1577.jpg',
#  'archive (2)/data/train\\benign\\158.jpg',
#  'archive (2)/data/train\\benign\\1580.jpg',
#  'archive (2)/data/train\\benign\\1581.jpg',
#  'archive (2)/data/train\\benign\\1582.jpg',
#  'archive (2)/data/train\\benign\\1583.jpg',
#  'archive (2)/data/train\\benign\\1584.jpg',
#  'archive (2)/data/train\\benign\\1585.jpg',
#  'archive (2)/data/train\\benign\\1586.jpg',
#  'archive (2)/data/train\\benign\\1587.jpg',
#  'archive (2)/data/train\\benign\\1588.jpg',
#  'archive (2)/data/train\\benign\\1589.jpg',
#  'archive (2)/data/train\\benign\\159.jpg',
#  'archive (2)/data/train\\benign\\1590.jpg',
#  'archive (2)/data/train\\benign\\1591.jpg',
#  'archive (2)/data/train\\benign\\1593.jpg',
#  'archive (2)/data/train\\benign\\1594.jpg',
#  'archive (2)/data/train\\benign\\1595.jpg',
#  'archive (2)/data/train\\benign\\1596.jpg',
#  'archive (2)/data/train\\benign\\1597.jpg',
#  'archive (2)/data/train\\benign\\1598.jpg',
#  'archive (2)/data/train\\benign\\1599.jpg',
#  'archive (2)/data/train\\benign\\160.jpg',
#  'archive (2)/data/train\\benign\\1600.jpg',
#  'archive (2)/data/train\\benign\\1601.jpg',
#  'archive (2)/data/train\\benign\\1603.jpg',
#  'archive (2)/data/train\\benign\\1604.jpg',
#  'archive (2)/data/train\\benign\\1605.jpg',
#  'archive (2)/data/train\\benign\\1606.jpg',
#  'archive (2)/data/train\\benign\\1608.jpg',
#  'archive (2)/data/train\\benign\\1609.jpg',
#  'archive (2)/data/train\\benign\\1612.jpg',
#  'archive (2)/data/train\\benign\\1613.jpg',
#  'archive (2)/data/train\\benign\\1614.jpg',
#  'archive (2)/data/train\\benign\\1615.jpg',
#  'archive (2)/data/train\\benign\\1616.jpg',
#  'archive (2)/data/train\\benign\\1617.jpg',
#  'archive (2)/data/train\\benign\\1618.jpg',
#  'archive (2)/data/train\\benign\\1619.jpg',
#  'archive (2)/data/train\\benign\\162.jpg',
#  'archive (2)/data/train\\benign\\1620.jpg',
#  'archive (2)/data/train\\benign\\1621.jpg',
#  'archive (2)/data/train\\benign\\1622.jpg',
#  'archive (2)/data/train\\benign\\1623.jpg',
#  'archive (2)/data/train\\benign\\1624.jpg',
#  'archive (2)/data/train\\benign\\1625.jpg',
#  'archive (2)/data/train\\benign\\1626.jpg',
#  'archive (2)/data/train\\benign\\1627.jpg',
#  'archive (2)/data/train\\benign\\1629.jpg',
#  'archive (2)/data/train\\benign\\163.jpg',
#  'archive (2)/data/train\\benign\\1630.jpg',
#  'archive (2)/data/train\\benign\\1631.jpg',
#  'archive (2)/data/train\\benign\\1633.jpg',
#  'archive (2)/data/train\\benign\\1635.jpg',
#  'archive (2)/data/train\\benign\\1636.jpg',
#  'archive (2)/data/train\\benign\\1638.jpg',
#  'archive (2)/data/train\\benign\\1639.jpg',
#  'archive (2)/data/train\\benign\\164.jpg',
#  'archive (2)/data/train\\benign\\1640.jpg',
#  'archive (2)/data/train\\benign\\1641.jpg',
#  'archive (2)/data/train\\benign\\1643.jpg',
#  'archive (2)/data/train\\benign\\1644.jpg',
#  'archive (2)/data/train\\benign\\1645.jpg',
#  'archive (2)/data/train\\benign\\1647.jpg',
#  'archive (2)/data/train\\benign\\1649.jpg',
#  'archive (2)/data/train\\benign\\165.jpg',
#  'archive (2)/data/train\\benign\\1650.jpg',
#  'archive (2)/data/train\\benign\\1651.jpg',
#  'archive (2)/data/train\\benign\\1652.jpg',
#  'archive (2)/data/train\\benign\\1653.jpg',
#  'archive (2)/data/train\\benign\\1654.jpg',
#  'archive (2)/data/train\\benign\\1656.jpg',
#  'archive (2)/data/train\\benign\\1658.jpg',
#  'archive (2)/data/train\\benign\\1659.jpg',
#  'archive (2)/data/train\\benign\\166.jpg',
#  'archive (2)/data/train\\benign\\1660.jpg',
#  'archive (2)/data/train\\benign\\1661.jpg',
#  'archive (2)/data/train\\benign\\1662.jpg',
#  'archive (2)/data/train\\benign\\1663.jpg',
#  'archive (2)/data/train\\benign\\1664.jpg',
#  'archive (2)/data/train\\benign\\1665.jpg',
#  'archive (2)/data/train\\benign\\1666.jpg',
#  'archive (2)/data/train\\benign\\1667.jpg',
#  'archive (2)/data/train\\benign\\1668.jpg',
#  'archive (2)/data/train\\benign\\1669.jpg',
#  'archive (2)/data/train\\benign\\167.jpg',
#  'archive (2)/data/train\\benign\\1670.jpg',
#  'archive (2)/data/train\\benign\\1671.jpg',
#  'archive (2)/data/train\\benign\\1673.jpg',
#  'archive (2)/data/train\\benign\\1674.jpg',
#  'archive (2)/data/train\\benign\\1675.jpg',
#  'archive (2)/data/train\\benign\\1676.jpg',
#  'archive (2)/data/train\\benign\\1677.jpg',
#  'archive (2)/data/train\\benign\\1678.jpg',
#  'archive (2)/data/train\\benign\\1679.jpg',
#  'archive (2)/data/train\\benign\\168.jpg',
#  'archive (2)/data/train\\benign\\1680.jpg',
#  'archive (2)/data/train\\benign\\1681.jpg',
#  'archive (2)/data/train\\benign\\1683.jpg',
#  'archive (2)/data/train\\benign\\1684.jpg',
#  'archive (2)/data/train\\benign\\1685.jpg',
#  'archive (2)/data/train\\benign\\1686.jpg',
#  'archive (2)/data/train\\benign\\1688.jpg',
#  'archive (2)/data/train\\benign\\1689.jpg',
#  'archive (2)/data/train\\benign\\169.jpg',
#  'archive (2)/data/train\\benign\\1690.jpg',
#  'archive (2)/data/train\\benign\\1691.jpg',
#  'archive (2)/data/train\\benign\\1692.jpg',
#  'archive (2)/data/train\\benign\\1693.jpg',
#  'archive (2)/data/train\\benign\\1694.jpg',
#  'archive (2)/data/train\\benign\\1695.jpg',
#  'archive (2)/data/train\\benign\\1697.jpg',
#  'archive (2)/data/train\\benign\\1698.jpg',
#  'archive (2)/data/train\\benign\\1699.jpg',
#  'archive (2)/data/train\\benign\\17.jpg',
#  'archive (2)/data/train\\benign\\170.jpg',
#  'archive (2)/data/train\\benign\\1700.jpg',
#  'archive (2)/data/train\\benign\\1702.jpg',
#  'archive (2)/data/train\\benign\\1703.jpg',
#  'archive (2)/data/train\\benign\\1705.jpg',
#  'archive (2)/data/train\\benign\\1706.jpg',
#  'archive (2)/data/train\\benign\\1707.jpg',
#  'archive (2)/data/train\\benign\\1708.jpg',
#  'archive (2)/data/train\\benign\\1709.jpg',
#  'archive (2)/data/train\\benign\\171.jpg',
#  'archive (2)/data/train\\benign\\1712.jpg',
#  'archive (2)/data/train\\benign\\1713.jpg',
#  'archive (2)/data/train\\benign\\1715.jpg',
#  'archive (2)/data/train\\benign\\1716.jpg',
#  'archive (2)/data/train\\benign\\1717.jpg',
#  'archive (2)/data/train\\benign\\1718.jpg',
#  'archive (2)/data/train\\benign\\172.jpg',
#  'archive (2)/data/train\\benign\\1720.jpg',
#  'archive (2)/data/train\\benign\\1722.jpg',
#  'archive (2)/data/train\\benign\\1723.jpg',
#  'archive (2)/data/train\\benign\\1724.jpg',
#  'archive (2)/data/train\\benign\\1725.jpg',
#  'archive (2)/data/train\\benign\\1726.jpg',
#  'archive (2)/data/train\\benign\\1727.jpg',
#  'archive (2)/data/train\\benign\\1728.jpg',
#  'archive (2)/data/train\\benign\\1729.jpg',
#  'archive (2)/data/train\\benign\\173.jpg',
#  'archive (2)/data/train\\benign\\1730.jpg',
#  'archive (2)/data/train\\benign\\1732.jpg',
#  'archive (2)/data/train\\benign\\1733.jpg',
#  'archive (2)/data/train\\benign\\1734.jpg',
#  'archive (2)/data/train\\benign\\1735.jpg',
#  'archive (2)/data/train\\benign\\1736.jpg',
#  'archive (2)/data/train\\benign\\1738.jpg',
#  'archive (2)/data/train\\benign\\1739.jpg',
#  'archive (2)/data/train\\benign\\174.jpg',
#  'archive (2)/data/train\\benign\\1740.jpg',
#  'archive (2)/data/train\\benign\\1741.jpg',
#  'archive (2)/data/train\\benign\\1742.jpg',
#  'archive (2)/data/train\\benign\\1743.jpg',
#  'archive (2)/data/train\\benign\\1744.jpg',
#  'archive (2)/data/train\\benign\\1746.jpg',
#  'archive (2)/data/train\\benign\\1749.jpg',
#  'archive (2)/data/train\\benign\\175.jpg',
#  'archive (2)/data/train\\benign\\1750.jpg',
#  'archive (2)/data/train\\benign\\1751.jpg',
#  'archive (2)/data/train\\benign\\1752.jpg',
#  'archive (2)/data/train\\benign\\1753.jpg',
#  'archive (2)/data/train\\benign\\1754.jpg',
#  'archive (2)/data/train\\benign\\1755.jpg',
#  'archive (2)/data/train\\benign\\1759.jpg',
#  'archive (2)/data/train\\benign\\176.jpg',
#  'archive (2)/data/train\\benign\\1760.jpg',
#  'archive (2)/data/train\\benign\\1761.jpg',
#  'archive (2)/data/train\\benign\\1762.jpg',
#  'archive (2)/data/train\\benign\\1763.jpg',
#  'archive (2)/data/train\\benign\\1765.jpg',
#  'archive (2)/data/train\\benign\\1766.jpg',
#  'archive (2)/data/train\\benign\\1767.jpg',
#  'archive (2)/data/train\\benign\\1769.jpg',
#  'archive (2)/data/train\\benign\\177.jpg',
#  'archive (2)/data/train\\benign\\1770.jpg',
#  'archive (2)/data/train\\benign\\1771.jpg',
#  'archive (2)/data/train\\benign\\1772.jpg',
#  'archive (2)/data/train\\benign\\1774.jpg',
#  'archive (2)/data/train\\benign\\1775.jpg',
#  'archive (2)/data/train\\benign\\1776.jpg',
#  'archive (2)/data/train\\benign\\1777.jpg',
#  'archive (2)/data/train\\benign\\1778.jpg',
#  'archive (2)/data/train\\benign\\1779.jpg',
#  'archive (2)/data/train\\benign\\178.jpg',
#  'archive (2)/data/train\\benign\\1780.jpg',
#  'archive (2)/data/train\\benign\\1781.jpg',
#  'archive (2)/data/train\\benign\\1782.jpg',
#  'archive (2)/data/train\\benign\\1783.jpg',
#  'archive (2)/data/train\\benign\\1784.jpg',
#  'archive (2)/data/train\\benign\\1785.jpg',
#  'archive (2)/data/train\\benign\\1786.jpg',
#  'archive (2)/data/train\\benign\\1787.jpg',
#  'archive (2)/data/train\\benign\\1788.jpg',
#  'archive (2)/data/train\\benign\\1789.jpg',
#  'archive (2)/data/train\\benign\\179.jpg',
#  'archive (2)/data/train\\benign\\1790.jpg',
#  'archive (2)/data/train\\benign\\1791.jpg',
#  'archive (2)/data/train\\benign\\1792.jpg',
#  'archive (2)/data/train\\benign\\1793.jpg',
#  'archive (2)/data/train\\benign\\1794.jpg',
#  'archive (2)/data/train\\benign\\1795.jpg',
#  'archive (2)/data/train\\benign\\1796.jpg',
#  'archive (2)/data/train\\benign\\1799.jpg',
#  'archive (2)/data/train\\benign\\180.jpg',
#  'archive (2)/data/train\\benign\\181.jpg',
#  'archive (2)/data/train\\benign\\182.jpg',
#  'archive (2)/data/train\\benign\\183.jpg',
#  'archive (2)/data/train\\benign\\184.jpg',
#  'archive (2)/data/train\\benign\\187.jpg',
#  'archive (2)/data/train\\benign\\188.jpg',
#  'archive (2)/data/train\\benign\\189.jpg',
#  'archive (2)/data/train\\benign\\19.jpg',
#  'archive (2)/data/train\\benign\\190.jpg',
#  'archive (2)/data/train\\benign\\191.jpg',
#  'archive (2)/data/train\\benign\\192.jpg',
#  'archive (2)/data/train\\benign\\193.jpg',
#  'archive (2)/data/train\\benign\\194.jpg',
#  'archive (2)/data/train\\benign\\195.jpg',
#  'archive (2)/data/train\\benign\\196.jpg',
#  'archive (2)/data/train\\benign\\197.jpg',
#  'archive (2)/data/train\\benign\\198.jpg',
#  'archive (2)/data/train\\benign\\199.jpg',
#  'archive (2)/data/train\\benign\\20.jpg',
#  'archive (2)/data/train\\benign\\200.jpg',
#  'archive (2)/data/train\\benign\\201.jpg',
#  'archive (2)/data/train\\benign\\202.jpg',
#  'archive (2)/data/train\\benign\\203.jpg',
#  'archive (2)/data/train\\benign\\204.jpg',
#  'archive (2)/data/train\\benign\\206.jpg',
#  'archive (2)/data/train\\benign\\207.jpg',
#  'archive (2)/data/train\\benign\\208.jpg',
#  'archive (2)/data/train\\benign\\209.jpg',
#  'archive (2)/data/train\\benign\\21.jpg',
#  'archive (2)/data/train\\benign\\210.jpg',
#  'archive (2)/data/train\\benign\\212.jpg',
#  'archive (2)/data/train\\benign\\213.jpg',
#  'archive (2)/data/train\\benign\\214.jpg',
#  'archive (2)/data/train\\benign\\217.jpg',
#  'archive (2)/data/train\\benign\\218.jpg',
#  'archive (2)/data/train\\benign\\219.jpg',
#  'archive (2)/data/train\\benign\\22.jpg',
#  'archive (2)/data/train\\benign\\220.jpg',
#  'archive (2)/data/train\\benign\\221.jpg',
#  'archive (2)/data/train\\benign\\222.jpg',
#  'archive (2)/data/train\\benign\\223.jpg',
#  'archive (2)/data/train\\benign\\225.jpg',
#  'archive (2)/data/train\\benign\\227.jpg',
#  'archive (2)/data/train\\benign\\228.jpg',
#  'archive (2)/data/train\\benign\\229.jpg',
#  'archive (2)/data/train\\benign\\23.jpg',
#  'archive (2)/data/train\\benign\\230.jpg',
#  'archive (2)/data/train\\benign\\231.jpg',
#  'archive (2)/data/train\\benign\\232.jpg',
#  'archive (2)/data/train\\benign\\233.jpg',
#  'archive (2)/data/train\\benign\\234.jpg',
#  'archive (2)/data/train\\benign\\235.jpg',
#  'archive (2)/data/train\\benign\\236.jpg',
#  'archive (2)/data/train\\benign\\238.jpg',
#  'archive (2)/data/train\\benign\\239.jpg',
#  'archive (2)/data/train\\benign\\24.jpg',
#  'archive (2)/data/train\\benign\\240.jpg',
#  'archive (2)/data/train\\benign\\241.jpg',
#  'archive (2)/data/train\\benign\\242.jpg',
#  'archive (2)/data/train\\benign\\243.jpg',
#  'archive (2)/data/train\\benign\\244.jpg',
#  'archive (2)/data/train\\benign\\246.jpg',
#  'archive (2)/data/train\\benign\\247.jpg',
#  'archive (2)/data/train\\benign\\248.jpg',
#  'archive (2)/data/train\\benign\\249.jpg',
#  'archive (2)/data/train\\benign\\25.jpg',
#  'archive (2)/data/train\\benign\\252.jpg',
#  'archive (2)/data/train\\benign\\254.jpg',
#  'archive (2)/data/train\\benign\\255.jpg',
#  'archive (2)/data/train\\benign\\257.jpg',
#  'archive (2)/data/train\\benign\\258.jpg',
#  'archive (2)/data/train\\benign\\26.jpg',
#  'archive (2)/data/train\\benign\\260.jpg',
#  'archive (2)/data/train\\benign\\261.jpg',
#  'archive (2)/data/train\\benign\\262.jpg',
#  'archive (2)/data/train\\benign\\263.jpg',
#  'archive (2)/data/train\\benign\\264.jpg',
#  'archive (2)/data/train\\benign\\265.jpg',
#  'archive (2)/data/train\\benign\\266.jpg',
#  'archive (2)/data/train\\benign\\269.jpg',
#  'archive (2)/data/train\\benign\\27.jpg',
#  'archive (2)/data/train\\benign\\270.jpg',
#  'archive (2)/data/train\\benign\\271.jpg',
#  'archive (2)/data/train\\benign\\272.jpg',
#  'archive (2)/data/train\\benign\\274.jpg',
#  'archive (2)/data/train\\benign\\275.jpg',
#  'archive (2)/data/train\\benign\\276.jpg',
#  'archive (2)/data/train\\benign\\277.jpg',
#  'archive (2)/data/train\\benign\\278.jpg',
#  'archive (2)/data/train\\benign\\279.jpg',
#  'archive (2)/data/train\\benign\\28.jpg',
#  'archive (2)/data/train\\benign\\280.jpg',
#  'archive (2)/data/train\\benign\\281.jpg',
#  'archive (2)/data/train\\benign\\282.jpg',
#  'archive (2)/data/train\\benign\\283.jpg',
#  'archive (2)/data/train\\benign\\285.jpg',
#  'archive (2)/data/train\\benign\\286.jpg',
#  'archive (2)/data/train\\benign\\288.jpg',
#  'archive (2)/data/train\\benign\\29.jpg',
#  'archive (2)/data/train\\benign\\290.jpg',
#  'archive (2)/data/train\\benign\\292.jpg',
#  'archive (2)/data/train\\benign\\293.jpg',
#  'archive (2)/data/train\\benign\\294.jpg',
#  'archive (2)/data/train\\benign\\295.jpg',
#  'archive (2)/data/train\\benign\\296.jpg',
#  'archive (2)/data/train\\benign\\297.jpg',
#  'archive (2)/data/train\\benign\\298.jpg',
#  'archive (2)/data/train\\benign\\299.jpg',
#  'archive (2)/data/train\\benign\\3.jpg',
#  'archive (2)/data/train\\benign\\30.jpg',
#  'archive (2)/data/train\\benign\\301.jpg',
#  'archive (2)/data/train\\benign\\302.jpg',
#  'archive (2)/data/train\\benign\\305.jpg',
#  'archive (2)/data/train\\benign\\306.jpg',
#  'archive (2)/data/train\\benign\\307.jpg',
#  'archive (2)/data/train\\benign\\308.jpg',
#  'archive (2)/data/train\\benign\\309.jpg',
#  'archive (2)/data/train\\benign\\310.jpg',
#  'archive (2)/data/train\\benign\\312.jpg',
#  'archive (2)/data/train\\benign\\314.jpg',
#  'archive (2)/data/train\\benign\\315.jpg',
#  'archive (2)/data/train\\benign\\316.jpg',
#  'archive (2)/data/train\\benign\\318.jpg',
#  'archive (2)/data/train\\benign\\319.jpg',
#  'archive (2)/data/train\\benign\\32.jpg',
#  'archive (2)/data/train\\benign\\320.jpg',
#  'archive (2)/data/train\\benign\\321.jpg',
#  'archive (2)/data/train\\benign\\324.jpg',
#  'archive (2)/data/train\\benign\\325.jpg',
#  'archive (2)/data/train\\benign\\326.jpg',
#  'archive (2)/data/train\\benign\\327.jpg',
#  'archive (2)/data/train\\benign\\328.jpg',
#  'archive (2)/data/train\\benign\\329.jpg',
#  'archive (2)/data/train\\benign\\33.jpg',
#  'archive (2)/data/train\\benign\\331.jpg',
#  'archive (2)/data/train\\benign\\333.jpg',
#  'archive (2)/data/train\\benign\\334.jpg',
#  'archive (2)/data/train\\benign\\336.jpg',
#  'archive (2)/data/train\\benign\\337.jpg',
#  'archive (2)/data/train\\benign\\338.jpg',
#  'archive (2)/data/train\\benign\\339.jpg',
#  'archive (2)/data/train\\benign\\34.jpg',
#  'archive (2)/data/train\\benign\\340.jpg',
#  'archive (2)/data/train\\benign\\341.jpg',
#  'archive (2)/data/train\\benign\\342.jpg',
#  'archive (2)/data/train\\benign\\343.jpg',
#  'archive (2)/data/train\\benign\\345.jpg',
#  'archive (2)/data/train\\benign\\346.jpg',
#  'archive (2)/data/train\\benign\\347.jpg',
#  'archive (2)/data/train\\benign\\349.jpg',
#  'archive (2)/data/train\\benign\\35.jpg',
#  'archive (2)/data/train\\benign\\350.jpg',
#  'archive (2)/data/train\\benign\\351.jpg',
#  'archive (2)/data/train\\benign\\352.jpg',
#  'archive (2)/data/train\\benign\\353.jpg',
#  'archive (2)/data/train\\benign\\355.jpg',
#  'archive (2)/data/train\\benign\\357.jpg',
#  'archive (2)/data/train\\benign\\358.jpg',
#  'archive (2)/data/train\\benign\\359.jpg',
#  'archive (2)/data/train\\benign\\36.jpg',
#  'archive (2)/data/train\\benign\\360.jpg',
#  'archive (2)/data/train\\benign\\361.jpg',
#  'archive (2)/data/train\\benign\\362.jpg',
#  'archive (2)/data/train\\benign\\363.jpg',
#  'archive (2)/data/train\\benign\\364.jpg',
#  'archive (2)/data/train\\benign\\365.jpg',
#  'archive (2)/data/train\\benign\\366.jpg',
#  'archive (2)/data/train\\benign\\368.jpg',
#  'archive (2)/data/train\\benign\\370.jpg',
#  'archive (2)/data/train\\benign\\371.jpg',
#  'archive (2)/data/train\\benign\\372.jpg',
#  'archive (2)/data/train\\benign\\373.jpg',
#  'archive (2)/data/train\\benign\\374.jpg',
#  'archive (2)/data/train\\benign\\375.jpg',
#  'archive (2)/data/train\\benign\\376.jpg',
#  'archive (2)/data/train\\benign\\377.jpg',
#  'archive (2)/data/train\\benign\\38.jpg',
#  'archive (2)/data/train\\benign\\380.jpg',
#  'archive (2)/data/train\\benign\\381.jpg',
#  'archive (2)/data/train\\benign\\382.jpg',
#  'archive (2)/data/train\\benign\\383.jpg',
#  'archive (2)/data/train\\benign\\384.jpg',
#  'archive (2)/data/train\\benign\\386.jpg',
#  'archive (2)/data/train\\benign\\387.jpg',
#  'archive (2)/data/train\\benign\\39.jpg',
#  'archive (2)/data/train\\benign\\390.jpg',
#  'archive (2)/data/train\\benign\\391.jpg',
#  'archive (2)/data/train\\benign\\392.jpg',
#  'archive (2)/data/train\\benign\\393.jpg',
#  'archive (2)/data/train\\benign\\395.jpg',
#  'archive (2)/data/train\\benign\\396.jpg',
#  'archive (2)/data/train\\benign\\397.jpg',
#  'archive (2)/data/train\\benign\\398.jpg',
#  'archive (2)/data/train\\benign\\399.jpg',
#  'archive (2)/data/train\\benign\\4.jpg',
#  'archive (2)/data/train\\benign\\40.jpg',
#  'archive (2)/data/train\\benign\\400.jpg',
#  'archive (2)/data/train\\benign\\401.jpg',
#  'archive (2)/data/train\\benign\\402.jpg',
#  'archive (2)/data/train\\benign\\403.jpg',
#  'archive (2)/data/train\\benign\\405.jpg',
#  'archive (2)/data/train\\benign\\406.jpg',
#  'archive (2)/data/train\\benign\\408.jpg',
#  'archive (2)/data/train\\benign\\409.jpg',
#  'archive (2)/data/train\\benign\\41.jpg',
#  'archive (2)/data/train\\benign\\410.jpg',
#  'archive (2)/data/train\\benign\\411.jpg',
#  'archive (2)/data/train\\benign\\412.jpg',
#  'archive (2)/data/train\\benign\\413.jpg',
#  'archive (2)/data/train\\benign\\415.jpg',
#  'archive (2)/data/train\\benign\\416.jpg',
#  'archive (2)/data/train\\benign\\417.jpg',
#  'archive (2)/data/train\\benign\\418.jpg',
#  'archive (2)/data/train\\benign\\42.jpg',
#  'archive (2)/data/train\\benign\\420.jpg',
#  'archive (2)/data/train\\benign\\421.jpg',
#  'archive (2)/data/train\\benign\\422.jpg',
#  'archive (2)/data/train\\benign\\423.jpg',
#  'archive (2)/data/train\\benign\\424.jpg',
#  'archive (2)/data/train\\benign\\425.jpg',
#  'archive (2)/data/train\\benign\\426.jpg',
#  'archive (2)/data/train\\benign\\429.jpg',
#  'archive (2)/data/train\\benign\\43.jpg',
#  'archive (2)/data/train\\benign\\430.jpg',
#  'archive (2)/data/train\\benign\\431.jpg',
#  'archive (2)/data/train\\benign\\432.jpg',
#  'archive (2)/data/train\\benign\\434.jpg',
#  'archive (2)/data/train\\benign\\435.jpg',
#  'archive (2)/data/train\\benign\\438.jpg',
#  'archive (2)/data/train\\benign\\439.jpg',
#  'archive (2)/data/train\\benign\\440.jpg',
#  'archive (2)/data/train\\benign\\441.jpg',
#  'archive (2)/data/train\\benign\\442.jpg',
#  'archive (2)/data/train\\benign\\443.jpg',
#  'archive (2)/data/train\\benign\\445.jpg',
#  'archive (2)/data/train\\benign\\446.jpg',
#  'archive (2)/data/train\\benign\\447.jpg',
#  'archive (2)/data/train\\benign\\448.jpg',
#  'archive (2)/data/train\\benign\\450.jpg',
#  'archive (2)/data/train\\benign\\451.jpg',
#  'archive (2)/data/train\\benign\\452.jpg',
#  'archive (2)/data/train\\benign\\453.jpg',
#  'archive (2)/data/train\\benign\\455.jpg',
#  'archive (2)/data/train\\benign\\456.jpg',
#  'archive (2)/data/train\\benign\\458.jpg',
#  'archive (2)/data/train\\benign\\459.jpg',
#  'archive (2)/data/train\\benign\\46.jpg',
#  'archive (2)/data/train\\benign\\460.jpg',
#  'archive (2)/data/train\\benign\\461.jpg',
#  'archive (2)/data/train\\benign\\463.jpg',
#  'archive (2)/data/train\\benign\\464.jpg',
#  'archive (2)/data/train\\benign\\465.jpg',
#  'archive (2)/data/train\\benign\\466.jpg',
#  'archive (2)/data/train\\benign\\467.jpg',
#  'archive (2)/data/train\\benign\\468.jpg',
#  'archive (2)/data/train\\benign\\469.jpg',
#  'archive (2)/data/train\\benign\\47.jpg',
#  'archive (2)/data/train\\benign\\470.jpg',
#  'archive (2)/data/train\\benign\\471.jpg',
#  'archive (2)/data/train\\benign\\472.jpg',
#  'archive (2)/data/train\\benign\\473.jpg',
#  'archive (2)/data/train\\benign\\474.jpg',
#  'archive (2)/data/train\\benign\\476.jpg',
#  'archive (2)/data/train\\benign\\477.jpg',
#  'archive (2)/data/train\\benign\\478.jpg',
#  'archive (2)/data/train\\benign\\48.jpg',
#  'archive (2)/data/train\\benign\\480.jpg',
#  'archive (2)/data/train\\benign\\481.jpg',
#  'archive (2)/data/train\\benign\\482.jpg',
#  'archive (2)/data/train\\benign\\483.jpg',
#  'archive (2)/data/train\\benign\\485.jpg',
#  'archive (2)/data/train\\benign\\486.jpg',
#  'archive (2)/data/train\\benign\\487.jpg',
#  'archive (2)/data/train\\benign\\488.jpg',
#  'archive (2)/data/train\\benign\\489.jpg',
#  'archive (2)/data/train\\benign\\49.jpg',
#  'archive (2)/data/train\\benign\\490.jpg',
#  'archive (2)/data/train\\benign\\491.jpg',
#  'archive (2)/data/train\\benign\\492.jpg',
#  'archive (2)/data/train\\benign\\493.jpg',
#  ...]

# %%
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))
labels
# Out:
# ['benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  ...]

# %%
filepath = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')
data = pd.concat([filepath, labels], axis=1)
data = data.sample(frac=1).reset_index(drop=True)
data.head(5)
# Out:
#                                     Filepath      Label
# 0  archive (2)/data/train\malignant\1117.jpg  malignant
# 1     archive (2)/data/train\benign\1513.jpg     benign
# 2       archive (2)/data/train\benign\78.jpg     benign
# 3       archive (2)/data/train\benign\35.jpg     benign
# 4   archive (2)/data/train\malignant\115.jpg  malignant

# %%
#balancing

# %%
counts = data.Label.value_counts()
sns.barplot(x=counts.index, y=counts)
plt.xlabel('Type')
plt.xticks(rotation=90);

# %%
#balance by deleting extra images (Augmentor API)
#augmentation 
#GAN

# %%
total_samples = len(data)
malignant_count = data[data['Label'] == 'malignant'].shape[0]
benign_count = data[data['Label'] == 'benign'].shape[0]

# %%
print(f"Total Samples: {total_samples}")
print(f"Malignant Samples: {malignant_count}")
print(f"Benign Samples: {benign_count}")
# Out:
# Total Samples: 2637
# Malignant Samples: 1197
# Benign Samples: 1440

# %%
train, test = train_test_split(data, test_size=0.25, random_state=42)

# %%
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(10,8), subplot_kw={'xticks':[],'yticks':[]})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(data.Filepath[i]))
    ax.set_title(data.Label[i])
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_gen = train_datagen.flow_from_dataframe(
    dataframe=train,
    x_col='Filepath',
    y_col='Label',
    target_size=(100,100),
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42
)
valid_gen = train_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='Filepath',
    y_col='Label',
    target_size=(100,100),
    class_mode='categorical',
    batch_size=32,
    shuffle=False,
    seed=42
)
test_gen = test_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='Filepath',
    y_col='Label',
    target_size=(100,100),
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 1977 validated image filenames belonging to 2 classes.
# Found 660 validated image filenames belonging to 2 classes.
# Found 660 validated image filenames belonging to 2 classes.

# %%
pretrained_model = ResNet50(
    input_shape=(100,100, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

pretrained_model.trainable = False

# %%
inputs = pretrained_model.input

x = Dense(128, activation='relu')(pretrained_model.output)
x = Dense(128, activation='relu')(x)

outputs = Dense(2, activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
my_callbacks  = [EarlyStopping(monitor='val_accuracy',
                              min_delta=0,
                              patience=2,
                              mode='auto')]

# %%
history = model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=100
)
# Out:
# Epoch 1/100
# 62/62 [==============================] - 53s 414ms/step - loss: 0.4209 - accuracy: 0.8068 - val_loss: 0.3604 - val_accuracy: 0.8152
# Epoch 2/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.2849 - accuracy: 0.8720 - val_loss: 0.3759 - val_accuracy: 0.8318
# Epoch 3/100
# 62/62 [==============================] - 5s 75ms/step - loss: 0.2480 - accuracy: 0.8811 - val_loss: 0.3701 - val_accuracy: 0.8455
# Epoch 4/100
# 62/62 [==============================] - 5s 77ms/step - loss: 0.2083 - accuracy: 0.9145 - val_loss: 0.3458 - val_accuracy: 0.8439
# Epoch 5/100
# 62/62 [==============================] - 5s 76ms/step - loss: 0.1616 - accuracy: 0.9287 - val_loss: 0.3827 - val_accuracy: 0.8379
# Epoch 6/100
# 62/62 [==============================] - 5s 75ms/step - loss: 0.1425 - accuracy: 0.9428 - val_loss: 0.4262 - val_accuracy: 0.8348
# Epoch 7/100
# 62/62 [==============================] - 5s 77ms/step - loss: 0.1104 - accuracy: 0.9585 - val_loss: 0.4550 - val_accuracy: 0.8333
# Epoch 8/100
# 62/62 [==============================] - 5s 75ms/step - loss: 0.0889 - accuracy: 0.9666 - val_loss: 0.5202 - val_accuracy: 0.8242
# Epoch 9/100
# 62/62 [==============================] - 5s 76ms/step - loss: 0.0623 - accuracy: 0.9808 - val_loss: 0.4600 - val_accuracy: 0.8530
# Epoch 10/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0420 - accuracy: 0.9889 - val_loss: 0.5616 - val_accuracy: 0.8333
# Epoch 11/100
# 62/62 [==============================] - 5s 77ms/step - loss: 0.0289 - accuracy: 0.9904 - val_loss: 0.7637 - val_accuracy: 0.8303
# Epoch 12/100
# 62/62 [==============================] - 5s 76ms/step - loss: 0.0693 - accuracy: 0.9691 - val_loss: 0.5952 - val_accuracy: 0.8379
# Epoch 13/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0612 - accuracy: 0.9767 - val_loss: 0.6026 - val_accuracy: 0.8227
# Epoch 14/100
# 62/62 [==============================] - 5s 77ms/step - loss: 0.0363 - accuracy: 0.9848 - val_loss: 0.6617 - val_accuracy: 0.8333
# Epoch 15/100
# 62/62 [==============================] - 5s 76ms/step - loss: 0.0317 - accuracy: 0.9899 - val_loss: 0.6725 - val_accuracy: 0.8545
# Epoch 16/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0226 - accuracy: 0.9939 - val_loss: 0.6588 - val_accuracy: 0.8424
# Epoch 17/100
# 62/62 [==============================] - 5s 81ms/step - loss: 0.0287 - accuracy: 0.9909 - val_loss: 0.7446 - val_accuracy: 0.8606
# Epoch 18/100
# 62/62 [==============================] - 5s 79ms/step - loss: 0.0195 - accuracy: 0.9934 - val_loss: 0.7377 - val_accuracy: 0.8470
# Epoch 19/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.7637 - val_accuracy: 0.8379
# Epoch 20/100
# 62/62 [==============================] - 5s 78ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.7889 - val_accuracy: 0.8515
# Epoch 21/100
# 62/62 [==============================] - 5s 78ms/step - loss: 6.9971e-04 - accuracy: 1.0000 - val_loss: 0.7987 - val_accuracy: 0.8485
# Epoch 22/100
# 62/62 [==============================] - 5s 80ms/step - loss: 5.3893e-04 - accuracy: 1.0000 - val_loss: 0.8094 - val_accuracy: 0.8409
# Epoch 23/100
# 62/62 [==============================] - 5s 80ms/step - loss: 4.6236e-04 - accuracy: 1.0000 - val_loss: 0.8252 - val_accuracy: 0.8455
# Epoch 24/100
# 62/62 [==============================] - 5s 78ms/step - loss: 4.0240e-04 - accuracy: 1.0000 - val_loss: 0.8370 - val_accuracy: 0.8470
# Epoch 25/100
# 62/62 [==============================] - 5s 79ms/step - loss: 3.6217e-04 - accuracy: 1.0000 - val_loss: 0.8461 - val_accuracy: 0.8485
# Epoch 26/100
# 62/62 [==============================] - 5s 81ms/step - loss: 3.3216e-04 - accuracy: 1.0000 - val_loss: 0.8569 - val_accuracy: 0.8470
# Epoch 27/100
# 62/62 [==============================] - 5s 81ms/step - loss: 2.9977e-04 - accuracy: 1.0000 - val_loss: 0.8640 - val_accuracy: 0.8455
# Epoch 28/100
# 62/62 [==============================] - 5s 78ms/step - loss: 2.7199e-04 - accuracy: 1.0000 - val_loss: 0.8749 - val_accuracy: 0.8470
# Epoch 29/100
# 62/62 [==============================] - 5s 79ms/step - loss: 2.4720e-04 - accuracy: 1.0000 - val_loss: 0.8855 - val_accuracy: 0.8455
# Epoch 30/100
# 62/62 [==============================] - 5s 79ms/step - loss: 2.3279e-04 - accuracy: 1.0000 - val_loss: 0.8917 - val_accuracy: 0.8455
# Epoch 31/100
# 62/62 [==============================] - 5s 78ms/step - loss: 2.1381e-04 - accuracy: 1.0000 - val_loss: 0.8963 - val_accuracy: 0.8485
# Epoch 32/100
# 62/62 [==============================] - 5s 77ms/step - loss: 1.9745e-04 - accuracy: 1.0000 - val_loss: 0.9022 - val_accuracy: 0.8485
# Epoch 33/100
# 62/62 [==============================] - 5s 79ms/step - loss: 1.8247e-04 - accuracy: 1.0000 - val_loss: 0.9083 - val_accuracy: 0.8470
# Epoch 34/100
# 62/62 [==============================] - 5s 78ms/step - loss: 1.6978e-04 - accuracy: 1.0000 - val_loss: 0.9206 - val_accuracy: 0.8470
# Epoch 35/100
# 62/62 [==============================] - 5s 78ms/step - loss: 1.5950e-04 - accuracy: 1.0000 - val_loss: 0.9267 - val_accuracy: 0.8485
# Epoch 36/100
# 62/62 [==============================] - 5s 77ms/step - loss: 1.4873e-04 - accuracy: 1.0000 - val_loss: 0.9305 - val_accuracy: 0.8485
# Epoch 37/100
# 62/62 [==============================] - 5s 77ms/step - loss: 1.3920e-04 - accuracy: 1.0000 - val_loss: 0.9373 - val_accuracy: 0.8485
# Epoch 38/100
# 62/62 [==============================] - 5s 77ms/step - loss: 1.3129e-04 - accuracy: 1.0000 - val_loss: 0.9430 - val_accuracy: 0.8485
# Epoch 39/100
# 62/62 [==============================] - 5s 78ms/step - loss: 1.2264e-04 - accuracy: 1.0000 - val_loss: 0.9466 - val_accuracy: 0.8470
# Epoch 40/100
# 62/62 [==============================] - 5s 78ms/step - loss: 1.1666e-04 - accuracy: 1.0000 - val_loss: 0.9540 - val_accuracy: 0.8500
# Epoch 41/100
# 62/62 [==============================] - 5s 80ms/step - loss: 1.1031e-04 - accuracy: 1.0000 - val_loss: 0.9612 - val_accuracy: 0.8485
# Epoch 42/100
# 62/62 [==============================] - 5s 82ms/step - loss: 1.0183e-04 - accuracy: 1.0000 - val_loss: 0.9691 - val_accuracy: 0.8485
# Epoch 43/100
# 62/62 [==============================] - 5s 78ms/step - loss: 9.6851e-05 - accuracy: 1.0000 - val_loss: 0.9725 - val_accuracy: 0.8470
# Epoch 44/100
# 62/62 [==============================] - 5s 79ms/step - loss: 9.1351e-05 - accuracy: 1.0000 - val_loss: 0.9794 - val_accuracy: 0.8485
# Epoch 45/100
# 62/62 [==============================] - 5s 82ms/step - loss: 8.6420e-05 - accuracy: 1.0000 - val_loss: 0.9838 - val_accuracy: 0.8500
# Epoch 46/100
# 62/62 [==============================] - 5s 78ms/step - loss: 8.1274e-05 - accuracy: 1.0000 - val_loss: 0.9891 - val_accuracy: 0.8485
# Epoch 47/100
# 62/62 [==============================] - 5s 83ms/step - loss: 7.7332e-05 - accuracy: 1.0000 - val_loss: 0.9941 - val_accuracy: 0.8470
# Epoch 48/100
# 62/62 [==============================] - 5s 81ms/step - loss: 7.3610e-05 - accuracy: 1.0000 - val_loss: 1.0007 - val_accuracy: 0.8485
# Epoch 49/100
# 62/62 [==============================] - 5s 78ms/step - loss: 7.0440e-05 - accuracy: 1.0000 - val_loss: 1.0038 - val_accuracy: 0.8485
# Epoch 50/100
# 62/62 [==============================] - 5s 79ms/step - loss: 6.6579e-05 - accuracy: 1.0000 - val_loss: 1.0089 - val_accuracy: 0.8470
# Epoch 51/100
# 62/62 [==============================] - 5s 79ms/step - loss: 6.2364e-05 - accuracy: 1.0000 - val_loss: 1.0170 - val_accuracy: 0.8470
# Epoch 52/100
# 62/62 [==============================] - 5s 79ms/step - loss: 6.0396e-05 - accuracy: 1.0000 - val_loss: 1.0219 - val_accuracy: 0.8470
# Epoch 53/100
# 62/62 [==============================] - 5s 79ms/step - loss: 5.6803e-05 - accuracy: 1.0000 - val_loss: 1.0233 - val_accuracy: 0.8485
# Epoch 54/100
# 62/62 [==============================] - 5s 81ms/step - loss: 5.4312e-05 - accuracy: 1.0000 - val_loss: 1.0284 - val_accuracy: 0.8455
# Epoch 55/100
# 62/62 [==============================] - 5s 81ms/step - loss: 5.1753e-05 - accuracy: 1.0000 - val_loss: 1.0334 - val_accuracy: 0.8470
# Epoch 56/100
# 62/62 [==============================] - 5s 82ms/step - loss: 4.9155e-05 - accuracy: 1.0000 - val_loss: 1.0373 - val_accuracy: 0.8455
# Epoch 57/100
# 62/62 [==============================] - 5s 82ms/step - loss: 4.7123e-05 - accuracy: 1.0000 - val_loss: 1.0430 - val_accuracy: 0.8455
# Epoch 58/100
# 62/62 [==============================] - 5s 83ms/step - loss: 4.5385e-05 - accuracy: 1.0000 - val_loss: 1.0467 - val_accuracy: 0.8455
# Epoch 59/100
# 62/62 [==============================] - 5s 84ms/step - loss: 4.3086e-05 - accuracy: 1.0000 - val_loss: 1.0518 - val_accuracy: 0.8439
# Epoch 60/100
# 62/62 [==============================] - 5s 85ms/step - loss: 4.0760e-05 - accuracy: 1.0000 - val_loss: 1.0566 - val_accuracy: 0.8455
# Epoch 61/100
# 62/62 [==============================] - 5s 85ms/step - loss: 3.8986e-05 - accuracy: 1.0000 - val_loss: 1.0642 - val_accuracy: 0.8485
# Epoch 62/100
# 62/62 [==============================] - 5s 84ms/step - loss: 3.7488e-05 - accuracy: 1.0000 - val_loss: 1.0670 - val_accuracy: 0.8470
# Epoch 63/100
# 62/62 [==============================] - 6s 89ms/step - loss: 3.5533e-05 - accuracy: 1.0000 - val_loss: 1.0722 - val_accuracy: 0.8485
# Epoch 64/100
# 62/62 [==============================] - 5s 84ms/step - loss: 3.4045e-05 - accuracy: 1.0000 - val_loss: 1.0753 - val_accuracy: 0.8439
# Epoch 65/100
# 62/62 [==============================] - 6s 90ms/step - loss: 3.2390e-05 - accuracy: 1.0000 - val_loss: 1.0795 - val_accuracy: 0.8439
# Epoch 66/100
# 62/62 [==============================] - 6s 93ms/step - loss: 3.1210e-05 - accuracy: 1.0000 - val_loss: 1.0842 - val_accuracy: 0.8485
# Epoch 67/100
# 62/62 [==============================] - 6s 88ms/step - loss: 2.9577e-05 - accuracy: 1.0000 - val_loss: 1.0880 - val_accuracy: 0.8455
# Epoch 68/100
# 62/62 [==============================] - 5s 88ms/step - loss: 2.8443e-05 - accuracy: 1.0000 - val_loss: 1.0941 - val_accuracy: 0.8485
# Epoch 69/100
# 62/62 [==============================] - 5s 85ms/step - loss: 2.7269e-05 - accuracy: 1.0000 - val_loss: 1.0958 - val_accuracy: 0.8455
# Epoch 70/100
# 62/62 [==============================] - 5s 86ms/step - loss: 2.6156e-05 - accuracy: 1.0000 - val_loss: 1.0997 - val_accuracy: 0.8455
# Epoch 71/100
# 62/62 [==============================] - 5s 88ms/step - loss: 2.4862e-05 - accuracy: 1.0000 - val_loss: 1.1052 - val_accuracy: 0.8455
# Epoch 72/100
# 62/62 [==============================] - 6s 89ms/step - loss: 2.4103e-05 - accuracy: 1.0000 - val_loss: 1.1094 - val_accuracy: 0.8439
# Epoch 73/100
# 62/62 [==============================] - 5s 87ms/step - loss: 2.2797e-05 - accuracy: 1.0000 - val_loss: 1.1162 - val_accuracy: 0.8485
# Epoch 74/100
# 62/62 [==============================] - 5s 86ms/step - loss: 2.2056e-05 - accuracy: 1.0000 - val_loss: 1.1169 - val_accuracy: 0.8455
# Epoch 75/100
# 62/62 [==============================] - 5s 87ms/step - loss: 2.1036e-05 - accuracy: 1.0000 - val_loss: 1.1218 - val_accuracy: 0.8439
# Epoch 76/100
# 62/62 [==============================] - 5s 87ms/step - loss: 2.0102e-05 - accuracy: 1.0000 - val_loss: 1.1265 - val_accuracy: 0.8439
# Epoch 77/100
# 62/62 [==============================] - 5s 85ms/step - loss: 1.9289e-05 - accuracy: 1.0000 - val_loss: 1.1296 - val_accuracy: 0.8455
# Epoch 78/100
# 62/62 [==============================] - 5s 84ms/step - loss: 1.8643e-05 - accuracy: 1.0000 - val_loss: 1.1352 - val_accuracy: 0.8470
# Epoch 79/100
# 62/62 [==============================] - 5s 86ms/step - loss: 1.7685e-05 - accuracy: 1.0000 - val_loss: 1.1387 - val_accuracy: 0.8439
# Epoch 80/100
# 62/62 [==============================] - 5s 85ms/step - loss: 1.7089e-05 - accuracy: 1.0000 - val_loss: 1.1417 - val_accuracy: 0.8439
# Epoch 81/100
# 62/62 [==============================] - 5s 85ms/step - loss: 1.6222e-05 - accuracy: 1.0000 - val_loss: 1.1459 - val_accuracy: 0.8455
# Epoch 82/100
# 62/62 [==============================] - 5s 85ms/step - loss: 1.5706e-05 - accuracy: 1.0000 - val_loss: 1.1495 - val_accuracy: 0.8455
# Epoch 83/100
# 62/62 [==============================] - 5s 85ms/step - loss: 1.5064e-05 - accuracy: 1.0000 - val_loss: 1.1540 - val_accuracy: 0.8455
# Epoch 84/100
# 62/62 [==============================] - 5s 85ms/step - loss: 1.4419e-05 - accuracy: 1.0000 - val_loss: 1.1588 - val_accuracy: 0.8439
# Epoch 85/100
# 62/62 [==============================] - 5s 88ms/step - loss: 1.3735e-05 - accuracy: 1.0000 - val_loss: 1.1604 - val_accuracy: 0.8455
# Epoch 86/100
# 62/62 [==============================] - 6s 89ms/step - loss: 1.3317e-05 - accuracy: 1.0000 - val_loss: 1.1656 - val_accuracy: 0.8455
# Epoch 87/100
# 62/62 [==============================] - 5s 82ms/step - loss: 1.2681e-05 - accuracy: 1.0000 - val_loss: 1.1697 - val_accuracy: 0.8439
# Epoch 88/100
# 62/62 [==============================] - 5s 79ms/step - loss: 1.2255e-05 - accuracy: 1.0000 - val_loss: 1.1751 - val_accuracy: 0.8439
# Epoch 89/100
# 62/62 [==============================] - 5s 77ms/step - loss: 1.1692e-05 - accuracy: 1.0000 - val_loss: 1.1770 - val_accuracy: 0.8455
# Epoch 90/100
# 62/62 [==============================] - 5s 79ms/step - loss: 1.1319e-05 - accuracy: 1.0000 - val_loss: 1.1831 - val_accuracy: 0.8439
# Epoch 91/100
# 62/62 [==============================] - 5s 77ms/step - loss: 1.0754e-05 - accuracy: 1.0000 - val_loss: 1.1867 - val_accuracy: 0.8439
# Epoch 92/100
# 62/62 [==============================] - 5s 78ms/step - loss: 1.0395e-05 - accuracy: 1.0000 - val_loss: 1.1929 - val_accuracy: 0.8470
# Epoch 93/100
# 62/62 [==============================] - 5s 80ms/step - loss: 9.8591e-06 - accuracy: 1.0000 - val_loss: 1.1963 - val_accuracy: 0.8455
# Epoch 94/100
# 62/62 [==============================] - 5s 78ms/step - loss: 9.5312e-06 - accuracy: 1.0000 - val_loss: 1.1999 - val_accuracy: 0.8439
# Epoch 95/100
# 62/62 [==============================] - 5s 77ms/step - loss: 9.0268e-06 - accuracy: 1.0000 - val_loss: 1.2035 - val_accuracy: 0.8439
# Epoch 96/100
# 62/62 [==============================] - 5s 76ms/step - loss: 8.7344e-06 - accuracy: 1.0000 - val_loss: 1.2095 - val_accuracy: 0.8470
# Epoch 97/100
# 62/62 [==============================] - 5s 77ms/step - loss: 8.3220e-06 - accuracy: 1.0000 - val_loss: 1.2115 - val_accuracy: 0.8424
# Epoch 98/100
# 62/62 [==============================] - 5s 76ms/step - loss: 7.9635e-06 - accuracy: 1.0000 - val_loss: 1.2162 - val_accuracy: 0.8424
# Epoch 99/100
# 62/62 [==============================] - 5s 77ms/step - loss: 7.6794e-06 - accuracy: 1.0000 - val_loss: 1.2200 - val_accuracy: 0.8424
# Epoch 100/100
# 62/62 [==============================] - 5s 77ms/step - loss: 7.2977e-06 - accuracy: 1.0000 - val_loss: 1.2218 - val_accuracy: 0.8424

# %%
model.save("model_SkinCancer.h5")

# %%
pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.title("Accuracy")
plt.show()

pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.title("Loss")
plt.show()

# %%
results = model.evaluate(test_gen, verbose=0)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
#     Test Loss: 1.22177
# Test Accuracy: 84.24%

# %%
# Predict the label of the test_gen
pred = model.predict(test_gen)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (train_gen.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]
# Out:
# 21/21 [==============================] - 2s 62ms/step

# %%
y_test = list(test.Label)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.86      0.85      0.86       362
#    malignant       0.82      0.84      0.83       298
#
#     accuracy                           0.84       660
#    macro avg       0.84      0.84      0.84       660
# weighted avg       0.84      0.84      0.84       660

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(12, 8),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test.Filepath.iloc[i]))
    ax.set_title(f"True: {test.Label.iloc[i]}\nPredicted: {pred[i]}")
plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
 
# Load the trained model
model = load_model("model_SkinCancer.h5")

# Define the path to the downloaded image
custom_image_path = "Skin_Cancer_Custom/bgn1.jpg"

# Function to classify custom input and display the image
def classify_and_display(custom_image_path):
    # Preprocess the input image
    img = image.load_img(custom_image_path, target_size=(100, 100))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    # Make predictions
    predictions = model.predict(img_array)

    # Post-process predictions
    predicted_class_index = np.argmax(predictions)
    class_labels = {0: 'benign', 1: 'malignant'}
    predicted_class_label = class_labels[predicted_class_index]
    confidence = predictions[0][predicted_class_index]

    # Display the image and prediction details
    img = mpimg.imread(custom_image_path)
    plt.imshow(img)
    plt.title(f"The predicted class is: {predicted_class_label}\nAccuracy: {confidence:.2%}")
    plt.axis('off')
    plt.show()

# Classify and display the downloaded image
classify_and_display(custom_image_path)
# Out:
# 1/1 [==============================] - 2s 2s/step
